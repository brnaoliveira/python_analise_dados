# %% [markdown]
# # Jogo da forca

# %%
import random

# %%
board = ['''
>>>>>>>>>>Hangman<<<<<<<<<<
+---+
|   |
    |
    |
    |
    |
=========''', '''
+---+
|   |
O   |
    |
    |
    |
=========''', '''
+---+
|   |
O   |
|   |
    |
    |
=========''', '''
 +---+
 |   |
 O   |
/|   |
     |
     |
=========''', '''
 +---+
 |   |
 O   |
/|\  |
     |
     |
=========''', '''
 +---+
 |   |
 O   |
/|\  |
/    |
     |
=========''', '''
 +---+
 |   |
 O   |
/|\  |
/ \  |
     |
=========''']

# %%
#classe
class Hangman:
    #Método construtor
    def __init__(self, word):
        self.word = word
        self.missed_letters = []
        self.guessed_letters = []
        
    
    #Método para adivinhar a letra
    def guess(self, letter):
        if letter in sel.word and letter not in self.guessed_letters:
            self.guessed_letters.append(letter)
        elif letter not in self.word and letter not in self.missed_letters:
            self.missed_letters.append(letter)
        else:
            return False
        
        return True
        
    
    #Método para verificar se o jogo terminou
    def hangman_over(self):
        
        return self.hangman_won() or (len(self.missed_letters) == 6)
        
        
    #Método para verificar se o jogador venceu
    def hangman_won(self):
        
        if '_' not in self.hide_word():
            
            return True
        
        
        return False
        
    
    #Método para não mostrar a lera no board
    def hide_word(self):
        
        rtn = ''
        for letter in self.word:
            if letter not in self.guessed_letters:
                rtn += '_'
            else:
                rtn += letter
            
        return rtn
        
        
    #Método para checar o status do game e imprimir o board na tela
    def print_game_status(self):
        print (board[len(self.missed_letters)])
        print ('\n')
        print('Palavra: ',self.hide_word())
        print ('\n')
        print('Letras erradas: ') 
        for letter in self.missed_letters:
            print (letter,) 
        print ()
        print ('Letras corretas: ',)
        for letter in self.guessed_letters:
            print (letter,)
        print ()
        
        
        

#Função para ler uma palavra de forma aleatoria

def rand_word():
    with open("palavras.txt", "rt") as f:
        bank = f.readlines()
        
    return bank[random.randint(0,len(bank))].strip()


# Função Main - Execução do programa
def main():
    
    #objeto
    game= Hangman(rand_word())
    
    #Enquanto o jogo não tiver terminado, print do status, solicita uma letra e faz a leitura do caracter
    
    while not game.hangman_over():
        game.print_game_status()
        user_input = input('\nDigite uma letra: ')
        game.guess(user_input)
    
    #Verifica o status do jogo
    game.print_game_status()
    
    
    
    #De acordo com o status, imprime mensagem na tela para o usuario
    
    if game.hangman_won():
        print('\n'+'Parabéns! Você venceu!')
        
    else:
        print('\n'+'Game over! Você perdeu!')
        print('A palavra era ', game.word)
        
    
    print ('\n'+'Foi bom jogar com você! Agora vá estudar!\n')
    
    
#Executa o programa

if __name__ == "__main__":
    main()
# Out:
# >>>>>>>>>>Hangman<<<<<<<<<<
# +---+
# |   |
#     |
#     |
#     |
#     |
# ...
#
#
# Palavra:  _______
#
#
# Letras erradas:
#
# Letras corretas:
#
#
# Digite uma letra: a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 112>()
#     110 #Executa o programa
#     112 if __name__ == "__main__":
# --> 113     main()
#
# Input In [3], in main()
#      88     game.print_game_status()
#      89     user_input = input('\nDigite uma letra: ')
# ---> 90     game.guess(user_input)
#      92 #Verifica o status do jogo
#      93 game.print_game_status()
#
# Input In [3], in Hangman.guess(self, letter)
#      11 def guess(self, letter):
# ---> 12     if letter in sel.word and letter not in self.guessed_letters:
#      13         self.guessed_letters.append(letter)
#      14     elif letter not in self.word and letter not in self.missed_letters:
#
# ...
